# %% [markdown]
# ---
# title: "Lecture title — Self-study notebook"
# subtitle: "Applied Differential Privacy"
# format:
#   html:
#     toc: true
#     code-tools: true
#     code-fold: true
# execute:
#   enabled: true
#   warning: false
#   message: false
# jupyter: python3
# ---
#
# Self-study companion to the presentation deck. Import computation from `libdpy` only.

# %%
try:
    import libdpy
except ImportError:
    # %pip install -q "libdpy @ git+https://github.com/applied-dp-course/pub_lib.git"
    import libdpy

# %% [markdown]
# ## Playable animation (optional)
#
# To add a playable plot sequence (step through, or press play), create a build sidecar at `animations/<name>.py` in this folder that defines a `frames()` generator plus `FPS`/`OUTPUTS`, then embed the generated player here:
#
# ```{=html}
# <iframe src="../../../_generated/animations/blog-posts/<this-folder>/<name>.html" width="100%" height="430" style="border:0" onload="this.style.height=this.contentWindow.document.documentElement.scrollHeight+'px'"></iframe>
# ```
#
# Set `OUTPUTS = ("gif",)` instead to emit a downloadable `.gif`/`.mp4`. See `authoring/examples/animated-plot-sequence/` and `authoring/AUTHORING.md`.
